# %% [markdown]
# [![Dataflowr](https://raw.githubusercontent.com/dataflowr/website/master/_assets/dataflowr_logo.png)](https://dataflowr.github.io/website/)

# %% [markdown]
# # [Module 5](https://dataflowr.github.io/website/modules/5-stacking-layers/): overfitting a MLP on CIFAR10
#
# Training loop over CIFAR10 (40,000 train images, 10,000 test images). What happens if you
# - switch the training to a GPU? Is it faster?
# - Remove the `ReLU()`?
# - Increase the learning rate?
# - Stack more layers?
# - Perform more epochs?
#
# Can you completely overfit the training set (i.e. get 100% accuracy?)
#
# This code is highly non-modulable. Create functions for each specific task.
# (hint: see [this](https://github.com/pytorch/examples/blob/master/mnist/main.py))
#
# Your training went well. Good. Why not save the weights of the network (`net.state_dict()`) using `torch.save()`?

# %%
import torch
import torchvision
import torch.nn as nn
import torchvision.transforms as t

# define network structure 
net = nn.Sequential(nn.Linear(3 * 32 * 32, 1000), nn.ReLU(), nn.Linear(1000, 10))
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

# load data
to_tensor =  t.ToTensor()
normalize = t.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
flatten =  t.Lambda(lambda x:x.view(-1))

transform_list = t.Compose([to_tensor, normalize, flatten])
train_set = torchvision.datasets.CIFAR10(root='.', train=True, transform=transform_list, download=True)
test_set = torchvision.datasets.CIFAR10(root='.', train=False, transform=transform_list, download=True)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=64)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=64)

# === Train === ###
net.train()

# train loop
for epoch in range(3):
    train_correct = 0
    train_loss = 0
    print('Epoch {}'.format(epoch))
    
    # loop per epoch 
    for i, (batch, targets) in enumerate(train_loader):
        output = net(batch)
        loss = criterion(output, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        pred = output.max(1, keepdim=True)[1]
        train_correct += pred.eq(targets.view_as(pred)).sum().item()
        train_loss += loss

        if i % 100 == 10: print('Train loss {:.4f}, Train accuracy {:.2f}%'.format(
            train_loss / ((i+1) * 64), 100 * train_correct / ((i+1) * 64)))
        
print('End of training.\n')
    
# === Test === ###
test_correct = 0
net.eval()

# loop, over whole test set
for i, (batch, targets) in enumerate(test_loader):
    output = net(batch)
    pred = output.max(1, keepdim=True)[1]
    test_correct += pred.eq(targets.view_as(pred)).sum().item()
    
print('End of testing. Test accuracy {:.2f}%'.format(
    100 * test_correct / (len(test_loader) * 64)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0
# Train loss 0.0338, Train accuracy 20.74%
# Train loss 0.0294, Train accuracy 32.05%
# Train loss 0.0284, Train accuracy 35.09%
# Train loss 0.0278, Train accuracy 36.54%
# Train loss 0.0272, Train accuracy 38.04%
# Train loss 0.0268, Train accuracy 38.97%
# Train loss 0.0265, Train accuracy 39.79%
# Train loss 0.0262, Train accuracy 40.40%
# Epoch 1
# Train loss 0.0236, Train accuracy 47.44%
# Train loss 0.0235, Train accuracy 46.31%
# Train loss 0.0234, Train accuracy 47.17%
# Train loss 0.0232, Train accuracy 47.81%
# Train loss 0.0229, Train accuracy 48.24%
# Train loss 0.0228, Train accuracy 48.57%
# Train loss 0.0227, Train accuracy 48.72%
# Train loss 0.0226, Train accuracy 49.10%
# Epoch 2
# Train loss 0.0211, Train accuracy 51.70%
# Train loss 0.0212, Train accuracy 51.68%
# Train loss 0.0212, Train accuracy 51.95%
# Train loss 0.0211, Train accuracy 52.17%
# Train loss 0.0209, Train accuracy 52.55%
# Train loss 0.0207, Train accuracy 52.83%
# Train loss 0.0207, Train accuracy 53.14%
# Train loss 0.0206, Train accuracy 53.41%
# Epoch 3
# Train loss 0.0188, Train accuracy 58.52%
# Train loss 0.0194, Train accuracy 55.80%
# Train loss 0.0194, Train accuracy 55.64%
# Train loss 0.0193, Train accuracy 56.15%
# Train loss 0.0191, Train accuracy 56.30%
# Train loss 0.0191, Train accuracy 56.42%
# Train loss 0.0190, Train accuracy 56.67%
# Train loss 0.0189, Train accuracy 56.93%
# Epoch 4
# Train loss 0.0169, Train accuracy 64.06%
# Train loss 0.0179, Train accuracy 59.46%
# Train loss 0.0179, Train accuracy 59.06%
# Train loss 0.0178, Train accuracy 59.29%
# Train loss 0.0176, Train accuracy 59.65%
# Train loss 0.0176, Train accuracy 59.82%
# Train loss 0.0175, Train accuracy 59.90%
# Train loss 0.0174, Train accuracy 60.23%
# Epoch 5
# Train loss 0.0154, Train accuracy 64.77%
# Train loss 0.0163, Train accuracy 62.54%
# Train loss 0.0166, Train accuracy 62.05%
# Train loss 0.0164, Train accuracy 62.39%
# Train loss 0.0163, Train accuracy 62.39%
# Train loss 0.0162, Train accuracy 62.65%
# Train loss 0.0161, Train accuracy 62.91%
# Train loss 0.0160, Train accuracy 63.22%
# Epoch 6
# Train loss 0.0139, Train accuracy 69.60%
# Train loss 0.0153, Train accuracy 64.81%
# Train loss 0.0155, Train accuracy 64.72%
# Train loss 0.0153, Train accuracy 65.09%
# Train loss 0.0152, Train accuracy 65.04%
# Train loss 0.0150, Train accuracy 65.43%
# Train loss 0.0149, Train accuracy 65.55%
# Train loss 0.0148, Train accuracy 65.84%
# Epoch 7
# Train loss 0.0122, Train accuracy 71.59%
# Train loss 0.0138, Train accuracy 67.84%
# Train loss 0.0142, Train accuracy 67.27%
# Train loss 0.0141, Train accuracy 67.34%
# Train loss 0.0141, Train accuracy 67.42%
# Train loss 0.0139, Train accuracy 67.81%
# Train loss 0.0138, Train accuracy 68.07%
# Train loss 0.0138, Train accuracy 68.16%
# Epoch 8
# Train loss 0.0117, Train accuracy 71.73%
# Train loss 0.0128, Train accuracy 70.03%
# Train loss 0.0132, Train accuracy 69.39%
# Train loss 0.0130, Train accuracy 69.99%
# Train loss 0.0129, Train accuracy 69.99%
# Train loss 0.0128, Train accuracy 70.42%
# Train loss 0.0128, Train accuracy 70.57%
# Train loss 0.0127, Train accuracy 70.70%
# Epoch 9
# Train loss 0.0105, Train accuracy 76.70%
# Train loss 0.0120, Train accuracy 72.14%
# Train loss 0.0122, Train accuracy 71.30%
# Train loss 0.0120, Train accuracy 71.93%
# Train loss 0.0120, Train accuracy 71.84%
# Train loss 0.0119, Train accuracy 72.30%
# Train loss 0.0119, Train accuracy 72.40%
# Train loss 0.0118, Train accuracy 72.60%
# Epoch 10
# Train loss 0.0100, Train accuracy 77.70%
# Train loss 0.0110, Train accuracy 74.25%
# Train loss 0.0115, Train accuracy 73.52%
# Train loss 0.0113, Train accuracy 73.95%
# Train loss 0.0112, Train accuracy 74.18%
# Train loss 0.0111, Train accuracy 74.44%
# Train loss 0.0110, Train accuracy 74.69%
# Train loss 0.0110, Train accuracy 74.71%
# Epoch 11
# Train loss 0.0084, Train accuracy 80.54%
# Train loss 0.0103, Train accuracy 76.22%
# Train loss 0.0108, Train accuracy 75.25%
# Train loss 0.0106, Train accuracy 75.77%
# Train loss 0.0105, Train accuracy 75.87%
# Train loss 0.0104, Train accuracy 76.13%
# Train loss 0.0104, Train accuracy 76.20%
# Train loss 0.0103, Train accuracy 76.25%
# Epoch 12
# Train loss 0.0084, Train accuracy 78.69%
# Train loss 0.0094, Train accuracy 77.62%
# Train loss 0.0099, Train accuracy 76.85%
# Train loss 0.0097, Train accuracy 77.55%
# Train loss 0.0097, Train accuracy 77.60%
# Train loss 0.0096, Train accuracy 77.89%
# Train loss 0.0096, Train accuracy 77.92%
# Train loss 0.0095, Train accuracy 78.12%
# Epoch 13
# Train loss 0.0083, Train accuracy 80.82%
# Train loss 0.0094, Train accuracy 78.79%
# Train loss 0.0097, Train accuracy 77.84%
# Train loss 0.0095, Train accuracy 78.31%
# Train loss 0.0094, Train accuracy 78.68%
# Train loss 0.0093, Train accuracy 78.94%
# Train loss 0.0092, Train accuracy 79.12%
# Train loss 0.0091, Train accuracy 79.26%
# Epoch 14
# Train loss 0.0079, Train accuracy 82.95%
# Train loss 0.0093, Train accuracy 79.21%
# Train loss 0.0095, Train accuracy 78.71%
# Train loss 0.0091, Train accuracy 79.53%
# Train loss 0.0090, Train accuracy 79.61%
# Train loss 0.0088, Train accuracy 79.99%
# Train loss 0.0088, Train accuracy 80.08%
# Train loss 0.0088, Train accuracy 80.07%
# Epoch 15
# Train loss 0.0073, Train accuracy 83.24%
# Train loss 0.0083, Train accuracy 81.42%
# Train loss 0.0086, Train accuracy 80.59%
# Train loss 0.0084, Train accuracy 81.04%
# Train loss 0.0083, Train accuracy 81.27%
# Train loss 0.0082, Train accuracy 81.43%
# Train loss 0.0082, Train accuracy 81.46%
# Train loss 0.0081, Train accuracy 81.59%
# Epoch 16
# Train loss 0.0067, Train accuracy 84.94%
# Train loss 0.0085, Train accuracy 81.18%
# Train loss 0.0087, Train accuracy 80.64%
# Train loss 0.0082, Train accuracy 81.53%
# Train loss 0.0081, Train accuracy 81.84%
# Train loss 0.0079, Train accuracy 82.12%
# Train loss 0.0079, Train accuracy 82.27%
# Train loss 0.0078, Train accuracy 82.41%
# Epoch 17
# Train loss 0.0076, Train accuracy 81.53%
# Train loss 0.0077, Train accuracy 82.60%
# Train loss 0.0079, Train accuracy 82.31%
# Train loss 0.0077, Train accuracy 82.93%
# Train loss 0.0076, Train accuracy 83.05%
# Train loss 0.0075, Train accuracy 83.17%
# Train loss 0.0075, Train accuracy 83.18%
# Train loss 0.0075, Train accuracy 83.13%
# Epoch 18
# Train loss 0.0059, Train accuracy 86.22%
# Train loss 0.0073, Train accuracy 83.50%
# Train loss 0.0076, Train accuracy 82.95%
# Train loss 0.0074, Train accuracy 83.35%
# Train loss 0.0073, Train accuracy 83.40%
# Train loss 0.0073, Train accuracy 83.53%
# Train loss 0.0072, Train accuracy 83.60%
# Train loss 0.0072, Train accuracy 83.79%
# Epoch 19
# Train loss 0.0058, Train accuracy 85.80%
# Train loss 0.0066, Train accuracy 84.54%
# Train loss 0.0070, Train accuracy 84.12%
# Train loss 0.0068, Train accuracy 84.53%
# Train loss 0.0067, Train accuracy 84.50%
# Train loss 0.0067, Train accuracy 84.75%
# Train loss 0.0067, Train accuracy 84.79%
# Train loss 0.0067, Train accuracy 84.79%
# Epoch 20
# Train loss 0.0067, Train accuracy 85.51%
# Train loss 0.0067, Train accuracy 84.99%
# Train loss 0.0066, Train accuracy 84.86%
# Train loss 0.0065, Train accuracy 85.47%
# Train loss 0.0066, Train accuracy 85.47%
# Train loss 0.0065, Train accuracy 85.55%
# Train loss 0.0066, Train accuracy 85.50%
# Train loss 0.0065, Train accuracy 85.56%
# Epoch 21
# Train loss 0.0051, Train accuracy 88.49%
# Train loss 0.0062, Train accuracy 85.78%
# Train loss 0.0065, Train accuracy 85.19%
# Train loss 0.0065, Train accuracy 85.53%
# Train loss 0.0065, Train accuracy 85.52%
# Train loss 0.0063, Train accuracy 85.80%
# Train loss 0.0063, Train accuracy 85.89%
# Train loss 0.0063, Train accuracy 85.96%
# Epoch 22
# Train loss 0.0061, Train accuracy 86.22%
# Train loss 0.0063, Train accuracy 86.01%
# Train loss 0.0066, Train accuracy 85.29%
# Train loss 0.0064, Train accuracy 85.70%
# Train loss 0.0064, Train accuracy 85.81%
# Train loss 0.0064, Train accuracy 85.99%
# Train loss 0.0063, Train accuracy 86.05%
# Train loss 0.0063, Train accuracy 86.07%
# Epoch 23
# Train loss 0.0048, Train accuracy 88.35%
# Train loss 0.0061, Train accuracy 86.22%
# Train loss 0.0063, Train accuracy 85.79%
# Train loss 0.0061, Train accuracy 86.19%
# Train loss 0.0060, Train accuracy 86.57%
# Train loss 0.0059, Train accuracy 86.83%
# Train loss 0.0059, Train accuracy 86.80%
# Train loss 0.0060, Train accuracy 86.78%
# Epoch 24
# Train loss 0.0052, Train accuracy 87.64%
# Train loss 0.0058, Train accuracy 87.05%
# Train loss 0.0060, Train accuracy 86.86%
# Train loss 0.0060, Train accuracy 86.85%
# Train loss 0.0060, Train accuracy 86.78%
# Train loss 0.0059, Train accuracy 86.89%
# Train loss 0.0059, Train accuracy 87.01%
# Train loss 0.0058, Train accuracy 87.11%
# Epoch 25
# Train loss 0.0054, Train accuracy 86.93%
# Train loss 0.0058, Train accuracy 86.99%
# Train loss 0.0059, Train accuracy 86.93%
# Train loss 0.0058, Train accuracy 87.19%
# Train loss 0.0058, Train accuracy 87.28%
# Train loss 0.0058, Train accuracy 87.37%
# Train loss 0.0058, Train accuracy 87.32%
# Train loss 0.0058, Train accuracy 87.27%
# Epoch 26
# Train loss 0.0053, Train accuracy 87.78%
# Train loss 0.0054, Train accuracy 87.75%
# Train loss 0.0056, Train accuracy 87.41%
# Train loss 0.0056, Train accuracy 87.63%
# Train loss 0.0056, Train accuracy 87.71%
# Train loss 0.0056, Train accuracy 87.51%
# Train loss 0.0056, Train accuracy 87.69%
# Train loss 0.0055, Train accuracy 87.85%
# Epoch 27
# Train loss 0.0042, Train accuracy 90.20%
# Train loss 0.0053, Train accuracy 88.09%
# Train loss 0.0054, Train accuracy 88.11%
# Train loss 0.0054, Train accuracy 88.17%
# Train loss 0.0053, Train accuracy 88.44%
# Train loss 0.0052, Train accuracy 88.55%
# Train loss 0.0053, Train accuracy 88.38%
# Train loss 0.0053, Train accuracy 88.49%
# Epoch 28
# Train loss 0.0040, Train accuracy 90.48%
# Train loss 0.0048, Train accuracy 89.25%
# Train loss 0.0053, Train accuracy 88.61%
# Train loss 0.0052, Train accuracy 88.68%
# Train loss 0.0051, Train accuracy 88.84%
# Train loss 0.0051, Train accuracy 88.89%
# Train loss 0.0051, Train accuracy 88.78%
# Train loss 0.0051, Train accuracy 88.79%
# Epoch 29
# Train loss 0.0048, Train accuracy 89.63%
# Train loss 0.0051, Train accuracy 88.71%
# Train loss 0.0055, Train accuracy 87.94%
# Train loss 0.0055, Train accuracy 88.12%
# Train loss 0.0053, Train accuracy 88.39%
# Train loss 0.0052, Train accuracy 88.54%
# Train loss 0.0051, Train accuracy 88.69%
# Train loss 0.0051, Train accuracy 88.85%
# Epoch 30
# Train loss 0.0046, Train accuracy 90.34%
# Train loss 0.0048, Train accuracy 89.67%
# Train loss 0.0051, Train accuracy 89.15%
# Train loss 0.0051, Train accuracy 89.36%
# Train loss 0.0050, Train accuracy 89.32%
# Train loss 0.0050, Train accuracy 89.33%
# Train loss 0.0050, Train accuracy 89.26%
# Train loss 0.0049, Train accuracy 89.35%
# Epoch 31
# Train loss 0.0041, Train accuracy 89.91%
# Train loss 0.0050, Train accuracy 88.78%
# Train loss 0.0052, Train accuracy 88.64%
# Train loss 0.0050, Train accuracy 89.01%
# Train loss 0.0049, Train accuracy 89.28%
# Train loss 0.0048, Train accuracy 89.48%
# Train loss 0.0048, Train accuracy 89.58%
# Train loss 0.0048, Train accuracy 89.53%
# Epoch 32
# Train loss 0.0048, Train accuracy 89.63%
# Train loss 0.0050, Train accuracy 89.33%
# Train loss 0.0050, Train accuracy 88.92%
# Train loss 0.0049, Train accuracy 89.11%
# Train loss 0.0049, Train accuracy 89.35%
# Train loss 0.0048, Train accuracy 89.50%
# Train loss 0.0047, Train accuracy 89.66%
# Train loss 0.0047, Train accuracy 89.66%
# Epoch 33
# Train loss 0.0046, Train accuracy 90.91%
# Train loss 0.0046, Train accuracy 90.29%
# Train loss 0.0048, Train accuracy 89.77%
# Train loss 0.0047, Train accuracy 89.82%
# Train loss 0.0047, Train accuracy 89.96%
# Train loss 0.0046, Train accuracy 90.09%
# Train loss 0.0046, Train accuracy 90.18%
# Train loss 0.0046, Train accuracy 90.23%
# Epoch 34
# Train loss 0.0036, Train accuracy 92.05%
# Train loss 0.0048, Train accuracy 89.70%
# Train loss 0.0048, Train accuracy 89.58%
# Train loss 0.0047, Train accuracy 89.90%
# Train loss 0.0046, Train accuracy 90.17%
# Train loss 0.0046, Train accuracy 90.07%
# Train loss 0.0046, Train accuracy 90.01%
# Train loss 0.0046, Train accuracy 89.98%
# Epoch 35
# Train loss 0.0045, Train accuracy 89.35%
# Train loss 0.0048, Train accuracy 89.57%
# Train loss 0.0048, Train accuracy 89.49%
# Train loss 0.0048, Train accuracy 89.53%
# Train loss 0.0048, Train accuracy 89.76%
# Train loss 0.0046, Train accuracy 89.97%
# Train loss 0.0046, Train accuracy 90.04%
# Train loss 0.0045, Train accuracy 90.28%
# Epoch 36
# Train loss 0.0049, Train accuracy 89.49%
# Train loss 0.0046, Train accuracy 90.22%
# Train loss 0.0048, Train accuracy 89.83%
# Train loss 0.0047, Train accuracy 90.05%
# Train loss 0.0046, Train accuracy 90.23%
# Train loss 0.0046, Train accuracy 90.32%
# Train loss 0.0046, Train accuracy 90.17%
# Train loss 0.0046, Train accuracy 90.28%
# Epoch 37
# Train loss 0.0039, Train accuracy 89.91%
# Train loss 0.0046, Train accuracy 89.98%
# Train loss 0.0046, Train accuracy 89.99%
# Train loss 0.0045, Train accuracy 90.21%
# Train loss 0.0044, Train accuracy 90.52%
# Train loss 0.0043, Train accuracy 90.69%
# Train loss 0.0044, Train accuracy 90.47%
# Train loss 0.0044, Train accuracy 90.60%
# Epoch 38
# Train loss 0.0031, Train accuracy 93.47%
# Train loss 0.0046, Train accuracy 90.37%
# Train loss 0.0045, Train accuracy 90.46%
# Train loss 0.0044, Train accuracy 90.94%
# Train loss 0.0043, Train accuracy 91.06%
# Train loss 0.0043, Train accuracy 91.13%
# Train loss 0.0042, Train accuracy 91.25%
# Train loss 0.0042, Train accuracy 91.20%
# Epoch 39
# Train loss 0.0034, Train accuracy 91.34%
# Train loss 0.0041, Train accuracy 90.89%
# Train loss 0.0044, Train accuracy 90.64%
# Train loss 0.0043, Train accuracy 90.68%
# Train loss 0.0043, Train accuracy 90.71%
# Train loss 0.0043, Train accuracy 90.74%
# Train loss 0.0043, Train accuracy 90.83%
# Train loss 0.0043, Train accuracy 90.81%
# Epoch 40
# Train loss 0.0027, Train accuracy 93.18%
# Train loss 0.0041, Train accuracy 90.99%
# Train loss 0.0043, Train accuracy 90.59%
# Train loss 0.0043, Train accuracy 90.65%
# Train loss 0.0043, Train accuracy 90.69%
# Train loss 0.0043, Train accuracy 90.67%
# Train loss 0.0043, Train accuracy 90.70%
# Train loss 0.0043, Train accuracy 90.70%
# Epoch 41
# Train loss 0.0035, Train accuracy 92.19%
# Train loss 0.0037, Train accuracy 91.93%
# Train loss 0.0038, Train accuracy 91.82%
# Train loss 0.0039, Train accuracy 91.76%
# Train loss 0.0039, Train accuracy 91.76%
# Train loss 0.0038, Train accuracy 91.86%
# Train loss 0.0039, Train accuracy 91.77%
# Train loss 0.0039, Train accuracy 91.74%
# Epoch 42
# Train loss 0.0034, Train accuracy 92.33%
# Train loss 0.0039, Train accuracy 91.61%
# Train loss 0.0042, Train accuracy 91.09%
# Train loss 0.0042, Train accuracy 91.24%
# Train loss 0.0042, Train accuracy 91.18%
# Train loss 0.0042, Train accuracy 91.17%
# Train loss 0.0042, Train accuracy 91.16%
# Train loss 0.0042, Train accuracy 91.21%
# Epoch 43
# Train loss 0.0030, Train accuracy 92.90%
# Train loss 0.0037, Train accuracy 92.13%
# Train loss 0.0039, Train accuracy 91.71%
# Train loss 0.0040, Train accuracy 91.68%
# Train loss 0.0040, Train accuracy 91.71%
# Train loss 0.0040, Train accuracy 91.64%
# Train loss 0.0040, Train accuracy 91.59%
# Train loss 0.0041, Train accuracy 91.52%
# Epoch 44
# Train loss 0.0037, Train accuracy 90.91%
# Train loss 0.0045, Train accuracy 90.53%
# Train loss 0.0044, Train accuracy 90.80%
# Train loss 0.0043, Train accuracy 91.09%
# Train loss 0.0042, Train accuracy 91.31%
# Train loss 0.0041, Train accuracy 91.47%
# Train loss 0.0040, Train accuracy 91.61%
# Train loss 0.0040, Train accuracy 91.59%
# Epoch 45
# Train loss 0.0039, Train accuracy 92.47%
# Train loss 0.0039, Train accuracy 91.57%
# Train loss 0.0040, Train accuracy 91.31%
# Train loss 0.0039, Train accuracy 91.66%
# Train loss 0.0039, Train accuracy 91.71%
# Train loss 0.0038, Train accuracy 91.91%
# Train loss 0.0037, Train accuracy 92.06%
# Train loss 0.0036, Train accuracy 92.26%
# Epoch 46
# Train loss 0.0028, Train accuracy 94.18%
# Train loss 0.0033, Train accuracy 92.65%
# Train loss 0.0036, Train accuracy 92.51%
# Train loss 0.0036, Train accuracy 92.45%
# Train loss 0.0038, Train accuracy 92.10%
# Train loss 0.0038, Train accuracy 92.10%
# Train loss 0.0038, Train accuracy 92.07%
# Train loss 0.0038, Train accuracy 92.18%
# Epoch 47
# Train loss 0.0026, Train accuracy 94.74%
# Train loss 0.0040, Train accuracy 91.99%
# Train loss 0.0041, Train accuracy 91.71%
# Train loss 0.0040, Train accuracy 91.81%
# Train loss 0.0040, Train accuracy 91.78%
# Train loss 0.0040, Train accuracy 91.86%
# Train loss 0.0040, Train accuracy 91.88%
# Train loss 0.0040, Train accuracy 91.92%
# Epoch 48
# Train loss 0.0029, Train accuracy 92.76%
# Train loss 0.0035, Train accuracy 92.36%
# Train loss 0.0036, Train accuracy 92.48%
# Train loss 0.0036, Train accuracy 92.56%
# Train loss 0.0037, Train accuracy 92.43%
# Train loss 0.0036, Train accuracy 92.46%
# Train loss 0.0036, Train accuracy 92.57%
# Train loss 0.0036, Train accuracy 92.58%
# Epoch 49
# Train loss 0.0034, Train accuracy 93.04%
# Train loss 0.0040, Train accuracy 91.78%
# Train loss 0.0042, Train accuracy 91.54%
# Train loss 0.0041, Train accuracy 91.63%
# Train loss 0.0040, Train accuracy 91.86%
# Train loss 0.0039, Train accuracy 91.98%
# Train loss 0.0039, Train accuracy 92.04%
# Train loss 0.0039, Train accuracy 92.16%
# End of training.
#
# End of testing. Test accuracy 51.96%

# %%
class CIFAR_MODEL(nn.Module):
  def __init__(self) -> None:
      super(CIFAR_MODEL, self).__init__()
      self.layers = nn.Sequential(nn.Linear(3 * 32 * 32, 1000),
                                  nn.ReLU(),
                                  nn.Linear(1000, 10))
  def forward(self, x):
    x = self.layers(x)
    return x


def train_loop(model, train_loader, device, optimizer, epochs):
  # === Train === ###
  model.train()

  # train loop
  for epoch in range(3):
      train_correct = 0
      train_loss = 0
      print('Epoch {}'.format(epoch))
      
      # loop per epoch 
      for i, (batch, targets) in enumerate(train_loader):
        batch, targets = batch.to(device), targets.to(device)
        output = model(batch)
        loss = criterion(output, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        pred = output.max(1, keepdim=True)[1]
        train_correct += pred.eq(targets.view_as(pred)).sum().item()
        train_loss += loss.item()

        if i % 100 == 10: print('Train loss {:.4f}, Train accuracy {:.2f}%'.format(
              train_loss / ((i+1) * 64), 100 * train_correct / ((i+1) * 64)))


def test_loop(model, test_loader, device):
  # === Test === ###
  test_correct = 0
  model.eval()
  with torch.inference_mode():
    # loop, over whole test set
    for i, (batch, targets) in enumerate(test_loader):
        batch, targets = batch.to(device), targets.to(device)
        output = model(batch)
        pred = output.max(1, keepdim=True)[1]
        test_correct += pred.eq(targets.view_as(pred)).sum().item()

    print('End of testing. Test accuracy {:.2f}%'.format(
          100 * test_correct / (len(test_loader) * 64)))

# device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# instantiating the model 
model_0 = CIFAR_MODEL()
model_0 = model_0.to(device)
# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model_0.parameters(), lr=0.01, momentum=0.9)
# training
train_loop(model_0, train_loader, device, optimizer, 10)
test_loop(model_0, test_loader, device)
# Out:
# Epoch 0
# Train loss 0.0346, Train accuracy 18.04%
# Train loss 0.0295, Train accuracy 32.93%
# Train loss 0.0282, Train accuracy 36.60%
# Train loss 0.0274, Train accuracy 38.31%
# Train loss 0.0267, Train accuracy 39.91%
# Train loss 0.0263, Train accuracy 40.72%
# Train loss 0.0260, Train accuracy 41.38%
# Train loss 0.0258, Train accuracy 41.91%
# Epoch 1
# Train loss 0.0230, Train accuracy 49.86%
# Train loss 0.0230, Train accuracy 49.37%
# Train loss 0.0229, Train accuracy 49.04%
# Train loss 0.0228, Train accuracy 49.33%
# Train loss 0.0225, Train accuracy 49.65%
# Train loss 0.0225, Train accuracy 49.82%
# Train loss 0.0224, Train accuracy 49.93%
# Train loss 0.0224, Train accuracy 50.07%
# Epoch 2
# Train loss 0.0209, Train accuracy 54.26%
# Train loss 0.0212, Train accuracy 53.32%
# Train loss 0.0212, Train accuracy 52.98%
# Train loss 0.0211, Train accuracy 53.51%
# Train loss 0.0209, Train accuracy 53.74%
# Train loss 0.0208, Train accuracy 53.92%
# Train loss 0.0208, Train accuracy 53.84%
# Train loss 0.0208, Train accuracy 53.91%
# End of testing. Test accuracy 50.63%

# %% [markdown]
# ## Autograd tips and tricks

# %% [markdown]
# Pointers are everywhere!

# %%
net = nn.Linear(2, 2)
w = net.weight
print(w)

x = torch.rand(1, 2)
y = net(x).sum()
y.backward()
net.weight.data -= 0.01 * net.weight.grad # <--- What is this?
print(w)
# Out:
# Parameter containing:
# tensor([[-0.4018,  0.0834],
#         [ 0.2269,  0.2882]], requires_grad=True)
# Parameter containing:
# tensor([[-0.4020,  0.0823],
#         [ 0.2267,  0.2871]], requires_grad=True)

# %%
net = nn.Linear(2, 2)
w = net.weight.clone()
print(w)

x = torch.rand(1, 2)
y = net(x).sum()
y.backward()
net.weight.data -= 0.01 * net.weight.grad # <--- What is this?
print(w)
# Out:
# tensor([[ 0.5300,  0.3895],
#         [-0.1400, -0.5465]], grad_fn=<CloneBackward0>)
# tensor([[ 0.5300,  0.3895],
#         [-0.1400, -0.5465]], grad_fn=<CloneBackward0>)

# %% [markdown]
# Sharing weights

# %%
net = nn.Sequential(nn.Linear(2, 2), nn.Linear(2, 2))
net[0].weight = net[1].weight  # weight sharing

x = torch.rand(1, 2)
y = net(x).sum()
y.backward()
print(net[0].weight.grad)
print(net[1].weight.grad)
# Out:
# tensor([[ 1.2128,  0.3815],
#         [ 0.8211, -0.0821]])
# tensor([[ 1.2128,  0.3815],
#         [ 0.8211, -0.0821]])

# %% [markdown]
# [![Dataflowr](https://raw.githubusercontent.com/dataflowr/website/master/_assets/dataflowr_logo.png)](https://dataflowr.github.io/website/)
